# %%
import pandas as pd

# %%
schools = pd.read_csv("Resources/schools_complete.csv") #reading file 1
schools.head()
# Out:
#    School ID            school_name      type  size   budget
# 0          0      Huang High School  District  2917  1910635
# 1          1   Figueroa High School  District  2949  1884411
# 2          2    Shelton High School   Charter  1761  1056600
# 3          3  Hernandez High School  District  4635  3022020
# 4          4    Griffin High School   Charter  1468   917500

# %%
students = pd.read_csv("Resources/students_complete.csv") #reading file 2
students.head()
# Out:
#    Student ID       student_name gender grade        school_name  \
# 0           0       Paul Bradley      M   9th  Huang High School
# 1           1       Victor Smith      M  12th  Huang High School
# 2           2    Kevin Rodriguez      M  12th  Huang High School
# 3           3  Dr. Richard Scott      M  12th  Huang High School
# 4           4         Bonnie Ray      F   9th  Huang High School
#
#    reading_score  math_score
# 0             66          79
# 1             94          61
# 2             90          60
# 3             67          58
# 4             97          84

# %%
students.dtypes #seeing what type of data each column has in students df
# Out:
# Student ID        int64
# student_name     object
# gender           object
# grade            object
# school_name      object
# reading_score     int64
# math_score        int64
# dtype: object

# %%
schools.dtypes #seeing what type of data each column has in schools df
# Out:
# School ID       int64
# school_name    object
# type           object
# size            int64
# budget          int64
# dtype: object

# %%
schools['school_name'].nunique() #getting total number of schools
# Out:
# 15

# %%
students['student_name'].nunique() #getting total number of students
# Out:
# 32715

# %%
schools['budget'].sum() #getting total budget amount
# Out:
# 24649428

# %%
students['math_score'].mean()
# Out:
# 78.98537145774827

# %%
students['reading_score'].mean()
# Out:
# 81.87784018381414

# %%
passing_math = students.loc[students["math_score"] >= 70]
passing_math.head(20)
# Out:
#     Student ID       student_name gender grade        school_name  \
# 0            0       Paul Bradley      M   9th  Huang High School
# 4            4         Bonnie Ray      F   9th  Huang High School
# 5            5      Bryan Miranda      M   9th  Huang High School
# 6            6      Sheena Carter      F  11th  Huang High School
# 8            8       Michael Roth      M  10th  Huang High School
# 9            9     Matthew Greene      M  10th  Huang High School
# 10          10   Andrew Alexander      M  10th  Huang High School
# 11          11      Daniel Cooper      M  10th  Huang High School
# 12          12    Brittney Walker      F   9th  Huang High School
# 13          13       William Long      M   9th  Huang High School
# 15          15  Dr. Jordan Carson      M  11th  Huang High School
# 17          17  Kimberly Santiago      F   9th  Huang High School
# 19          19       Brandi Lyons      F   9th  Huang High School
# ...

# %%
students.describe()
# Out:
#          Student ID  reading_score    math_score
# count  39170.000000    39170.00000  39170.000000
# mean   19584.500000       81.87784     78.985371
# std    11307.549359       10.23958     12.309968
# min        0.000000       63.00000     55.000000
# 25%     9792.250000       73.00000     69.000000
# 50%    19584.500000       82.00000     79.000000
# 75%    29376.750000       91.00000     89.000000
# max    39169.000000       99.00000     99.000000
